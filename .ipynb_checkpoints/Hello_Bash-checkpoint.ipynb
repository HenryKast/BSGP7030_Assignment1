# %%
# Hello World in Bash
# This notebook demonstrates a Bash script using Jupyter's `%%bash` magic.

# %%
%%bash
echo "Hello, World from Bash!"
# Out:
# Error in parse(text = input): <text>:1:1: unexpected SPECIAL
# 1: %%
#     ^
# Traceback:

# %%
bashmagic
echo "Hello, World from Bash!"
# Out:
# Error in parse(text = input): <text>:2:6: unexpected string constant
# 1: bashmagic
# 2: echo "Hello, World from Bash!"
#         ^
# Traceback:

# %%
bash
echo "Hello World"
# Out:
# Error in parse(text = input): <text>:2:6: unexpected string constant
# 1: bash
# 2: echo "Hello World"
#         ^
# Traceback:
